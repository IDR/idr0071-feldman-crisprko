# %%
import omero.clients
import pandas as pd
from tqdm import tqdm

client = omero.client('localhost')
session = client.createSession(USERNAME, PASSWORD)
client.enableKeepAlive(60)
qs = client.getSession().getQueryService()

def batchgen(arr, size):
    for n in range(0, len(arr), size):
        yield arr[n:n + size]

# %%
datasets = omero.rtypes.unwrap(qs.projection("""
SELECT pdl.parent.name, pdl.child.name, pdl.child.id
FROM ProjectDatasetLink pdl
WHERE pdl.parent.name LIKE 'idr0071%'
""", None))
print(f'Datasets: [{len(datasets)}]')
# Out:
# Datasets: [512]

# %%
rs = []
for pname, dname, did in tqdm(datasets):
    r = omero.rtypes.unwrap(qs.projection(f"""
SELECT
    SUBSTRING(dlink.parent.name, 1, 1),
    SUBSTRING(dlink.parent.name, 3),
    uf.clientPath,
    image.name as image_name,
    pix.sizeX, pix.sizeY, pix.sizeZ, pix.sizeC, pix.sizeT
FROM Image image
LEFT OUTER JOIN image.pixels pix
JOIN image.fileset fs
JOIN fs.usedFiles uf
JOIN image.datasetLinks dlink
WHERE dlink.parent.id = {did}
""", None))
    rs.append(r)
# Out:
# 100%|██████████| 512/512 [03:03<00:00,  2.79it/s]

# %%
flattened = [item for sublist in rs for item in sublist]
df = pd.DataFrame(
    flattened,
    columns=('Experiment', 'Dataset', 'File', 'Image', 'X', 'Y', 'Z', 'C', 'T'))
df
# Out:
#        Experiment                         Dataset  \
# 0               B    phenotype_aligned B3 process
# 1               B    phenotype_aligned B3 process
# 2               B    phenotype_aligned B3 process
# 3               B    phenotype_aligned B3 process
# 4               B    phenotype_aligned B3 process
# ...           ...                             ...
# 205901          D  c0-DAPI-p65ab phenotype A1 raw
# 205902          D  c0-DAPI-p65ab phenotype A1 raw
# 205903          D  c0-DAPI-p65ab phenotype A1 raw
# 205904          D  c0-DAPI-p65ab phenotype A1 raw
# 205905          D  c0-DAPI-p65ab phenotype A1 raw
#
#                                                      File  \
# 0       uod/idr/filesets/idr0071-feldman-crisprko/2019...
# 1       uod/idr/filesets/idr0071-feldman-crisprko/2019...
# 2       uod/idr/filesets/idr0071-feldman-crisprko/2019...
# 3       uod/idr/filesets/idr0071-feldman-crisprko/2019...
# 4       uod/idr/filesets/idr0071-feldman-crisprko/2019...
# ...                                                   ...
# 205901  uod/idr/filesets/idr0071-feldman-crisprko/2019...
# 205902  uod/idr/filesets/idr0071-feldman-crisprko/2019...
# 205903  uod/idr/filesets/idr0071-feldman-crisprko/2019...
# 205904  uod/idr/filesets/idr0071-feldman-crisprko/2019...
# 205905  uod/idr/filesets/idr0071-feldman-crisprko/2020...
#
#                                          Image     X     Y  Z  C  T
# 0             10X_B3_Tile-10.phenotype_aligned  1024  1024  1  2  1
# 1            10X_B3_Tile-102.phenotype_aligned  1024  1024  1  2  1
# 2            10X_B3_Tile-104.phenotype_aligned  1024  1024  1  2  1
# 3            10X_B3_Tile-103.phenotype_aligned  1024  1024  1  2  1
# 4            10X_B3_Tile-116.phenotype_aligned  1024  1024  1  2  1
# ...                                        ...   ...   ... .. .. ..
# 205901   10X_c0-DAPI-p65ab_A1_Tile-9.phenotype  1024  1024  1  1  2
# 205902  10X_c0-DAPI-p65ab_A1_Tile-91.phenotype  1024  1024  1  1  2
# 205903  10X_c0-DAPI-p65ab_A1_Tile-96.phenotype  1024  1024  1  1  2
# 205904  10X_c0-DAPI-p65ab_A1_Tile-93.phenotype  1024  1024  1  1  2
# 205905   10X_c0-DAPI-p65ab_A1_Tile-7.phenotype  1024  1024  1  1  2
#
# [205906 rows x 9 columns]

# %% [markdown]
# ## Count images/dataset that have `C!=5` _and_ `Z>1` or `T>1`, suggesting the dimensions have been swapped.

# %%
# for d in 'XYZCT':
#     g = df.groupby([d, 'Experiment', 'Dataset'])['Image']
#     display(g.count())

cond = (df['C'] != 5) & ((df['Z'] > 1) | (df['T'] > 1))
g = df.loc[cond].groupby(['C', 'Experiment', 'Dataset'])['Image']
with pd.option_context('display.max_rows', None):
    display(g.count().to_frame())
# Out:
#                                              Image
# C Experiment Dataset
# 1 B          c10-SBS-10 sbs A1 raw             533
#              c10-SBS-10 sbs A2 raw             533
#              c10-SBS-10 sbs A3 raw             533
#              c10-SBS-10 sbs B1 raw             533
#              c10-SBS-10 sbs B2 raw             533
#              c10-SBS-10 sbs B3 raw             532
#              c2-SBS-2 sbs A1 raw               533
#              c2-SBS-2 sbs A2 raw               533
#              c2-SBS-2 sbs A3 raw               533
#              c2-SBS-2 sbs B1 raw               533
#              c2-SBS-2 sbs B2 raw               533
#              c2-SBS-2 sbs B3 raw               532
#              c3-SBS-3 sbs A1 raw               533
#              c3-SBS-3 sbs A2 raw               533
#              c3-SBS-3 sbs A3 raw               533
#              c3-SBS-3 sbs B1 raw               533
#              c3-SBS-3 sbs B2 raw               533
#              c3-SBS-3 sbs B3 raw               532
#              c5-SBS-5 sbs A1 raw               533
#              c5-SBS-5 sbs A2 raw               533
#              c5-SBS-5 sbs A3 raw               533
#              c5-SBS-5 sbs B1 raw               533
#              c5-SBS-5 sbs B2 raw               533
#              c5-SBS-5 sbs B3 raw               532
#              c6-SBS-6 sbs A1 raw               533
#              c6-SBS-6 sbs A2 raw               533
#              c6-SBS-6 sbs A3 raw               533
#              c6-SBS-6 sbs B1 raw               533
#              c6-SBS-6 sbs B2 raw               533
#              c6-SBS-6 sbs B3 raw               532
#              c7-SBS-7 sbs A1 raw               533
#              c7-SBS-7 sbs A2 raw               533
#              c7-SBS-7 sbs A3 raw               533
#              c7-SBS-7 sbs B1 raw               533
#              c7-SBS-7 sbs B2 raw               533
#              c7-SBS-7 sbs B3 raw               532
#              c8-SBS-8 sbs A1 raw               533
#              c8-SBS-8 sbs A2 raw               533
#              c8-SBS-8 sbs A3 raw               533
#              c8-SBS-8 sbs B1 raw               533
#              c8-SBS-8 sbs B2 raw               533
#              c8-SBS-8 sbs B3 raw               532
#              c9-SBS-9 sbs A1 raw               533
#              c9-SBS-9 sbs A2 raw               533
#              c9-SBS-9 sbs A3 raw               533
#              c9-SBS-9 sbs B1 raw               533
#              c9-SBS-9 sbs B2 raw               533
#              c9-SBS-9 sbs B3 raw               532
#   C          c0-DAPI-p65ab phenotype A1 raw    533
#              c0-DAPI-p65ab phenotype A2 raw    533
#              c0-DAPI-p65ab phenotype A3 raw    533
#              c0-DAPI-p65ab phenotype B1 raw    533
#              c0-DAPI-p65ab phenotype B2 raw    533
#              c0-DAPI-p65ab phenotype B3 raw    533
#              c1-SBS-1 sbs A1 raw               533
#              c1-SBS-1 sbs A2 raw               533
#              c1-SBS-1 sbs A3 raw               533
#              c1-SBS-1 sbs B1 raw               533
#              c1-SBS-1 sbs B2 raw               533
#              c1-SBS-1 sbs B3 raw               533
#              c10-SBS-10 sbs A1 raw             533
#              c10-SBS-10 sbs A2 raw             533
#              c10-SBS-10 sbs A3 raw             533
#              c10-SBS-10 sbs B1 raw             533
#              c10-SBS-10 sbs B2 raw             533
#              c10-SBS-10 sbs B3 raw             533
#              c2-SBS-2 sbs A1 raw               533
#              c2-SBS-2 sbs A2 raw               533
#              c2-SBS-2 sbs A3 raw               533
#              c2-SBS-2 sbs B1 raw               533
#              c2-SBS-2 sbs B2 raw               533
#              c2-SBS-2 sbs B3 raw               533
#              c3-SBS-3 sbs A1 raw               533
#              c3-SBS-3 sbs A2 raw               533
#              c3-SBS-3 sbs A3 raw               533
#              c3-SBS-3 sbs B1 raw               533
#              c3-SBS-3 sbs B2 raw               533
#              c3-SBS-3 sbs B3 raw               533
#              c4-SBS-4 sbs A1 raw               533
#              c4-SBS-4 sbs A2 raw               533
#              c4-SBS-4 sbs A3 raw               533
#              c4-SBS-4 sbs B1 raw               533
#              c4-SBS-4 sbs B2 raw               533
#              c4-SBS-4 sbs B3 raw               533
#              c5-SBS-5 sbs A1 raw               533
#              c5-SBS-5 sbs A2 raw               533
#              c5-SBS-5 sbs A3 raw               533
#              c5-SBS-5 sbs B1 raw               533
#              c5-SBS-5 sbs B2 raw               533
#              c5-SBS-5 sbs B3 raw               533
#              c7-SBS-7 sbs A1 raw               533
#              c7-SBS-7 sbs A2 raw               533
#              c7-SBS-7 sbs A3 raw               533
#              c7-SBS-7 sbs B1 raw               533
#              c7-SBS-7 sbs B2 raw               533
#              c7-SBS-7 sbs B3 raw               533
#              c8-SBS-8 sbs A1 raw               533
#              c8-SBS-8 sbs A2 raw               533
#              c8-SBS-8 sbs A3 raw               533
#              c8-SBS-8 sbs B1 raw               533
#              c8-SBS-8 sbs B2 raw               533
#              c8-SBS-8 sbs B3 raw               533
#              c9-SBS-9 sbs A1 raw               533
#              c9-SBS-9 sbs A2 raw               533
#              c9-SBS-9 sbs A3 raw               533
#              c9-SBS-9 sbs B1 raw               533
#              c9-SBS-9 sbs B2 raw               533
#              c9-SBS-9 sbs B3 raw               533
#   D          c0-DAPI-p65ab phenotype A1 raw    533
#              c0-DAPI-p65ab phenotype A2 raw    533
#              c0-DAPI-p65ab phenotype A3 raw    533
#              c0-DAPI-p65ab phenotype B1 raw    533
#              c0-DAPI-p65ab phenotype B2 raw    533
#              c0-DAPI-p65ab phenotype B3 raw    533
#              c1-SBS-1 sbs A1 raw               533
#              c1-SBS-1 sbs A2 raw               533
#              c1-SBS-1 sbs A3 raw               533
#              c1-SBS-1 sbs B1 raw               533
#              c1-SBS-1 sbs B2 raw               533
#              c1-SBS-1 sbs B3 raw               533
#              c2-SBS-2 sbs A1 raw               533
#              c2-SBS-2 sbs A2 raw               533
#              c2-SBS-2 sbs A3 raw               533
#              c2-SBS-2 sbs B1 raw               533
#              c2-SBS-2 sbs B2 raw               533
#              c2-SBS-2 sbs B3 raw               533
#              c3-SBS-3 sbs A1 raw               533
#              c3-SBS-3 sbs A2 raw               533
#              c3-SBS-3 sbs A3 raw               533
#              c3-SBS-3 sbs B1 raw               533
#              c3-SBS-3 sbs B2 raw               533
#              c3-SBS-3 sbs B3 raw               533
#              c4-SBS-4 sbs A1 raw               533
#              c4-SBS-4 sbs A2 raw               533
#              c4-SBS-4 sbs A3 raw               533
#              c4-SBS-4 sbs B1 raw               533
#              c4-SBS-4 sbs B2 raw               533
#              c4-SBS-4 sbs B3 raw               533
#              c5-SBS-5 sbs A1 raw               533
#              c5-SBS-5 sbs A2 raw               533
#              c5-SBS-5 sbs A3 raw               533
#              c5-SBS-5 sbs B1 raw               533
#              c5-SBS-5 sbs B2 raw               533
#              c5-SBS-5 sbs B3 raw               533
#              c6-SBS-6 sbs A1 raw               533
#              c6-SBS-6 sbs A2 raw               533
#              c6-SBS-6 sbs A3 raw               533
#              c6-SBS-6 sbs B1 raw               533
#              c6-SBS-6 sbs B2 raw               533
#              c6-SBS-6 sbs B3 raw               533
#              c7-SBS-7 sbs A1 raw               533
#              c7-SBS-7 sbs A2 raw               533
#              c7-SBS-7 sbs A3 raw               533
#              c7-SBS-7 sbs B1 raw               533
#              c7-SBS-7 sbs B2 raw               533
#              c7-SBS-7 sbs B3 raw               533
#              c8-SBS-8 sbs A1 raw               533
#              c8-SBS-8 sbs A2 raw               533
#              c8-SBS-8 sbs A3 raw               533
#              c8-SBS-8 sbs B1 raw               533
#              c8-SBS-8 sbs B2 raw               533
#              c8-SBS-8 sbs B3 raw               533
#              c9-SBS-9 sbs A1 raw               533
#              c9-SBS-9 sbs A2 raw               533
#              c9-SBS-9 sbs A3 raw               533
#              c9-SBS-9 sbs B1 raw               533
#              c9-SBS-9 sbs B2 raw               533
#              c9-SBS-9 sbs B3 raw               533
#   F          c1-SBS-1 sbs A1 raw               533
#              c1-SBS-1 sbs A2 raw               533
#              c1-SBS-1 sbs B1 raw               532
#              c1-SBS-1 sbs B2 raw               533
#              c2-SBS-2 sbs A1 raw               533
#              c2-SBS-2 sbs A2 raw               533
#              c2-SBS-2 sbs B1 raw               533
#              c2-SBS-2 sbs B2 raw               533
#              c3-SBS-3 sbs A1 raw               533
#              c3-SBS-3 sbs A2 raw               533
#              c3-SBS-3 sbs B1 raw               533
#              c3-SBS-3 sbs B2 raw               533
#              c4-SBS-4 sbs A1 raw               533
#              c4-SBS-4 sbs A2 raw               533
#              c4-SBS-4 sbs B1 raw               533
#              c4-SBS-4 sbs B2 raw               533
#              c5-SBS-5 sbs A1 raw               533
#              c5-SBS-5 sbs A2 raw               533
#              c5-SBS-5 sbs B1 raw               533
#              c5-SBS-5 sbs B2 raw               533
#              c6-SBS-6 sbs A1 raw               533
#              c6-SBS-6 sbs A2 raw               533
#              c6-SBS-6 sbs B1 raw               533
#              c6-SBS-6 sbs B2 raw               533

# %% [markdown]
# ## Invert the previous selection, i.e. these are the images we think are fine

# %%
g = df.loc[~cond].groupby(['C', 'Experiment', 'Dataset'])['Image']
with pd.option_context('display.max_rows', None):
    display(g.count().to_frame())
# Out:
#                                                 Image
# C Experiment Dataset
# 1 A          cells A1 process                     533
#              cells A2 process                     533
#              cells A3 process                     533
#              cells B1 process                     533
#              cells B2 process                     533
#              cells B3 process                     533
#              nuclei A1 process                    533
#              nuclei A2 process                    533
#              nuclei A3 process                    533
#              nuclei B1 process                    533
#              nuclei B2 process                    533
#              nuclei B3 process                    533
#   B          cells A1 process                     533
#              cells A2 process                     533
#              cells A3 process                     533
#              cells B1 process                     533
#              cells B2 process                     533
#              cells B3 process                     532
#              nuclei A1 process                    533
#              nuclei A2 process                    533
#              nuclei A3 process                    533
#              nuclei B1 process                    533
#              nuclei B2 process                    533
#              nuclei B3 process                    532
#   C          cells A1 process                     533
#              cells A2 process                     533
#              cells A3 process                     533
#              cells B1 process                     533
#              cells B2 process                     533
#              cells B3 process                     533
#              nuclei A1 process                    533
#              nuclei A2 process                    533
#              nuclei A3 process                    533
#              nuclei B1 process                    533
#              nuclei B2 process                    533
#              nuclei B3 process                    533
#   D          cells A1 process                     533
#              cells A2 process                     533
#              cells A3 process                     533
#              cells B1 process                     533
#              cells B2 process                     533
#              cells B3 process                     533
#              nuclei A1 process                    533
#              nuclei A2 process                    533
#              nuclei A3 process                    533
#              nuclei B1 process                    533
#              nuclei B2 process                    533
#              nuclei B3 process                    533
#   E          cells A11 process                     49
#              cells B10 process                     49
#              cells B11 process                     49
#              cells B12 process                     49
#              cells C10 process                     49
#              cells C11 process                     49
#              cells C12 process                     49
#              nuclei A11 process                    49
#              nuclei B10 process                    49
#              nuclei B11 process                    49
#              nuclei B12 process                    49
#              nuclei C10 process                    49
#              nuclei C11 process                    49
#              nuclei C12 process                    49
#   F          cells A1 process                     533
#              cells A2 process                     533
#              cells B1 process                     533
#              cells B2 process                     533
#              nuclei A1 process                    533
#              nuclei A2 process                    533
#              nuclei B1 process                    533
#              nuclei B2 process                    533
# 2 A          c0-DAPI-p65mNeon phenotype A1 raw    533
#              c0-DAPI-p65mNeon phenotype A2 raw    533
#              c0-DAPI-p65mNeon phenotype A3 raw    533
#              c0-DAPI-p65mNeon phenotype B1 raw    533
#              c0-DAPI-p65mNeon phenotype B2 raw    533
#              c0-DAPI-p65mNeon phenotype B3 raw    533
#              phenotype_aligned A1 process         533
#              phenotype_aligned A2 process         533
#              phenotype_aligned A3 process         533
#              phenotype_aligned B1 process         533
#              phenotype_aligned B2 process         533
#              phenotype_aligned B3 process         533
#   B          c0-DAPI-p65ab phenotype A1 raw       533
#              c0-DAPI-p65ab phenotype A2 raw       533
#              c0-DAPI-p65ab phenotype A3 raw       533
#              c0-DAPI-p65ab phenotype B1 raw       533
#              c0-DAPI-p65ab phenotype B2 raw       533
#              c0-DAPI-p65ab phenotype B3 raw       532
#              phenotype_aligned A1 process         533
#              phenotype_aligned A2 process         533
#              phenotype_aligned A3 process         533
#              phenotype_aligned B1 process         533
#              phenotype_aligned B2 process         533
#              phenotype_aligned B3 process         532
#   C          phenotype_aligned A1 process         533
#              phenotype_aligned A2 process         533
#              phenotype_aligned A3 process         533
#              phenotype_aligned B1 process         533
#              phenotype_aligned B2 process         533
#              phenotype_aligned B3 process         533
#   D          phenotype_aligned A1 process         533
#              phenotype_aligned A2 process         533
#              phenotype_aligned A3 process         533
#              phenotype_aligned B1 process         533
#              phenotype_aligned B2 process         533
#              phenotype_aligned B3 process         533
# 5 A          c1-SBS-1 sbs A1 raw                  533
#              c1-SBS-1 sbs A2 raw                  533
#              c1-SBS-1 sbs A3 raw                  533
#              c1-SBS-1 sbs B1 raw                  533
#              c1-SBS-1 sbs B2 raw                  533
#              c1-SBS-1 sbs B3 raw                  533
#              c2-SBS-2 sbs A1 raw                  533
#              c2-SBS-2 sbs A2 raw                  533
#              c2-SBS-2 sbs A3 raw                  533
#              c2-SBS-2 sbs B1 raw                  533
#              c2-SBS-2 sbs B2 raw                  533
#              c2-SBS-2 sbs B3 raw                  533
#              c3-SBS-3 sbs A1 raw                  533
#              c3-SBS-3 sbs A2 raw                  533
#              c3-SBS-3 sbs A3 raw                  533
#              c3-SBS-3 sbs B1 raw                  533
#              c3-SBS-3 sbs B2 raw                  533
#              c3-SBS-3 sbs B3 raw                  533
#              c4-SBS-4 sbs A1 raw                  533
#              c4-SBS-4 sbs A2 raw                  533
#              c4-SBS-4 sbs A3 raw                  533
#              c4-SBS-4 sbs B1 raw                  533
#              c4-SBS-4 sbs B2 raw                  533
#              c4-SBS-4 sbs B3 raw                  533
#              c5-SBS-5 sbs A1 raw                  533
#              c5-SBS-5 sbs A2 raw                  533
#              c5-SBS-5 sbs A3 raw                  533
#              c5-SBS-5 sbs B1 raw                  533
#              c5-SBS-5 sbs B2 raw                  533
#              c5-SBS-5 sbs B3 raw                  533
#              c6-SBS-6 sbs A1 raw                  533
#              c6-SBS-6 sbs A2 raw                  533
#              c6-SBS-6 sbs A3 raw                  533
#              c6-SBS-6 sbs B1 raw                  533
#              c6-SBS-6 sbs B2 raw                  533
#              c6-SBS-6 sbs B3 raw                  533
#              c7-SBS-7 sbs A1 raw                  533
#              c7-SBS-7 sbs A2 raw                  533
#              c7-SBS-7 sbs A3 raw                  533
#              c7-SBS-7 sbs B1 raw                  533
#              c7-SBS-7 sbs B2 raw                  533
#              c7-SBS-7 sbs B3 raw                  533
#              c8-SBS-8 sbs A1 raw                  533
#              c8-SBS-8 sbs A2 raw                  533
#              c8-SBS-8 sbs A3 raw                  533
#              c8-SBS-8 sbs B1 raw                  533
#              c8-SBS-8 sbs B2 raw                  533
#              c8-SBS-8 sbs B3 raw                  533
#              c9-SBS-9 sbs A1 raw                  533
#              c9-SBS-9 sbs A2 raw                  533
#              c9-SBS-9 sbs A3 raw                  533
#              c9-SBS-9 sbs B1 raw                  533
#              c9-SBS-9 sbs B2 raw                  533
#              c9-SBS-9 sbs B3 raw                  533
#              log A1 process                       533
#              log A2 process                       533
#              log A3 process                       532
#              log B1 process                       533
#              log B2 process                       533
#              log B3 process                       533
#   B          c1-SBS-1 sbs A1 raw                  533
#              c1-SBS-1 sbs A2 raw                  533
#              c1-SBS-1 sbs A3 raw                  533
#              c1-SBS-1 sbs B1 raw                  533
#              c1-SBS-1 sbs B2 raw                  533
#              c1-SBS-1 sbs B3 raw                  532
#              log A1 process                       533
#              log A2 process                       533
#              log A3 process                       533
#              log B1 process                       533
#              log B2 process                       533
#              log B3 process                       532
#   C          log A1 process                       533
#              log A2 process                       533
#              log A3 process                       533
#              log B1 process                       533
#              log B2 process                       533
#              log B3 process                       533
#   D          log A1 process                       533
#              log A2 process                       533
#              log A3 process                       533
#              log B1 process                       533
#              log B2 process                       533
#              log B3 process                       533
#   E          aligned A11 process                   49
#              aligned B10 process                   49
#              aligned B11 process                   49
#              aligned B12 process                   49
#              aligned C10 process                   49
#              aligned C11 process                   49
#              aligned C12 process                   49
#              c1-SBS-1 sbs A11 raw                  49
#              c1-SBS-1 sbs B10 raw                  49
#              c1-SBS-1 sbs B11 raw                  49
#              c1-SBS-1 sbs B12 raw                  49
#              c1-SBS-1 sbs C10 raw                  49
#              c1-SBS-1 sbs C11 raw                  49
#              c1-SBS-1 sbs C12 raw                  49
#              c10-SBS-10 sbs A11 raw                49
#              c10-SBS-10 sbs B10 raw                49
#              c10-SBS-10 sbs B11 raw                49
#              c10-SBS-10 sbs B12 raw                49
#              c10-SBS-10 sbs C10 raw                49
#              c10-SBS-10 sbs C11 raw                49
#              c10-SBS-10 sbs C12 raw                49
#              c11-SBS-11 sbs A11 raw                49
#              c11-SBS-11 sbs B10 raw                49
#              c11-SBS-11 sbs B11 raw                49
#              c11-SBS-11 sbs B12 raw                49
#              c11-SBS-11 sbs C10 raw                49
#              c11-SBS-11 sbs C11 raw                49
#              c11-SBS-11 sbs C12 raw                49
#              c12-SBS-12 sbs A11 raw                49
#              c12-SBS-12 sbs B10 raw                49
#              c12-SBS-12 sbs B11 raw                49
#              c12-SBS-12 sbs B12 raw                49
#              c12-SBS-12 sbs C10 raw                49
#              c12-SBS-12 sbs C11 raw                49
#              c12-SBS-12 sbs C12 raw                49
#              c2-SBS-2 sbs A11 raw                  49
#              c2-SBS-2 sbs B10 raw                  49
#              c2-SBS-2 sbs B11 raw                  49
#              c2-SBS-2 sbs B12 raw                  49
#              c2-SBS-2 sbs C10 raw                  49
#              c2-SBS-2 sbs C11 raw                  49
#              c2-SBS-2 sbs C12 raw                  49
#              c3-SBS-3 sbs A11 raw                  49
#              c3-SBS-3 sbs B10 raw                  49
#              c3-SBS-3 sbs B11 raw                  49
#              c3-SBS-3 sbs B12 raw                  49
#              c3-SBS-3 sbs C10 raw                  49
#              c3-SBS-3 sbs C11 raw                  49
#              c3-SBS-3 sbs C12 raw                  49
#              c4-SBS-4 sbs A11 raw                  49
#              c4-SBS-4 sbs B10 raw                  49
#              c4-SBS-4 sbs B11 raw                  49
#              c4-SBS-4 sbs B12 raw                  49
#              c4-SBS-4 sbs C10 raw                  49
#              c4-SBS-4 sbs C11 raw                  49
#              c4-SBS-4 sbs C12 raw                  49
#              c5-SBS-5 sbs A11 raw                  49
#              c5-SBS-5 sbs B10 raw                  49
#              c5-SBS-5 sbs B11 raw                  49
#              c5-SBS-5 sbs B12 raw                  49
#              c5-SBS-5 sbs C10 raw                  49
#              c5-SBS-5 sbs C11 raw                  49
#              c5-SBS-5 sbs C12 raw                  49
#              c6-SBS-6 sbs A11 raw                  49
#              c6-SBS-6 sbs B10 raw                  49
#              c6-SBS-6 sbs B11 raw                  49
#              c6-SBS-6 sbs B12 raw                  49
#              c6-SBS-6 sbs C10 raw                  49
#              c6-SBS-6 sbs C11 raw                  49
#              c6-SBS-6 sbs C12 raw                  49
#              c7-SBS-7 sbs A11 raw                  49
#              c7-SBS-7 sbs B10 raw                  49
#              c7-SBS-7 sbs B11 raw                  49
#              c7-SBS-7 sbs B12 raw                  49
#              c7-SBS-7 sbs C10 raw                  49
#              c7-SBS-7 sbs C11 raw                  49
#              c7-SBS-7 sbs C12 raw                  49
#              c8-SBS-8 sbs A11 raw                  49
#              c8-SBS-8 sbs B10 raw                  49
#              c8-SBS-8 sbs B11 raw                  49
#              c8-SBS-8 sbs B12 raw                  49
#              c8-SBS-8 sbs C10 raw                  49
#              c8-SBS-8 sbs C11 raw                  49
#              c8-SBS-8 sbs C12 raw                  49
#              c9-SBS-9 sbs A11 raw                  49
#              c9-SBS-9 sbs B10 raw                  49
#              c9-SBS-9 sbs B11 raw                  49
#              c9-SBS-9 sbs B12 raw                  49
#              c9-SBS-9 sbs C10 raw                  49
#              c9-SBS-9 sbs C11 raw                  49
#              c9-SBS-9 sbs C12 raw                  49
#              log A11 process                       49
#              log B10 process                       49
#              log B11 process                       49
#              log B12 process                       49
#              log C10 process                       49
#              log C11 process                       49
#              log C12 process                       49
#   F          aligned A1 process                   533
#              aligned A2 process                   533
#              aligned B1 process                   533
#              aligned B2 process                   533
#              c1-SBS-1 sbs B1 raw                   26
#              log A1 process                       533
#              log A2 process                       533
#              log B1 process                       533
#              log B2 process                       533
